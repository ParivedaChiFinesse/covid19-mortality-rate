# %%
# Setup and imports
# %matplotlib inline

import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
import pymc3 as pm

import seaborn as sns

from src.data import make_dataset
from src.features import build_features
from src.models import train_model

# %%
df = make_dataset.make_dataset()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-602e07149cac> in <module>
# ----> 1 df = make_dataset.make_dataset()
#
# ~/Documents/chi-finesse/covid19-mortality-rate/src/data/make_dataset.py in make_dataset()
#      58     * World Bank data on population, healthcare, etc. by country
#      59     '''
# ---> 60     _get_external_data(EXTERNAL_DATA_BUCKET)
#      61
#      62     all_covid_data = _get_latest_covid_timeseries()
#
# ~/Documents/chi-finesse/covid19-mortality-rate/src/data/make_dataset.py in _get_external_data(bucket)
#     102
#     103 def _get_external_data(bucket):
# --> 104     if not path.exists(EXTERNAL_DATA_DIR):
#     105         os.mkdir(EXTERNAL_DATA_DIR)
#     106
#
# NameError: name 'path' is not defined

# %%
build_features.build_features(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 153 entries, Afghanistan to Zimbabwe
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   cases                                  153 non-null    int64
#  1   deaths                                 153 non-null    int64
#  2   death_rate_observed                    153 non-null    float64
#  3   days_since_first_case                  153 non-null    int64
#  4   cpi_score_2019                         153 non-null    float64
#  5   healthcare_oop_expenditure             153 non-null    float64
#  6   hospital_beds                          141 non-null    float64
#  7   hci                                    137 non-null    float64
#  8   population_perc_over65                 153 non-null    float64
#  9   population_perc_rural                  153 non-null    float64
#  10  population_perc_diabetic               153 non-null    float64
#  11  days_since_first_case_normalized       153 non-null    float64
#  12  cpi_score_2019_normalized              153 non-null    float64
#  13  healthcare_oop_expenditure_normalized  153 non-null    float64
#  14  hospital_beds_normalized               141 non-null    float64
#  15  hci_normalized                         137 non-null    float64
#  16  population_perc_over65_normalized      153 non-null    float64
#  17  population_perc_rural_normalized       153 non-null    float64
#  18  population_perc_diabetic_normalized    153 non-null    float64
# dtypes: float64(16), int64(3)
# memory usage: 23.9+ KB

# %%
df.head(5)
# Out:
#                 cases  deaths  death_rate_observed  days_since_first_case  \
# Country/Region
# Afghanistan       996      33             0.033133                     55
# Albania           562      26             0.046263                     41
# Algeria          2629     375             0.142640                     54
# Angola             24       2             0.083333                     30
# Argentina        2839     132             0.046495                     47
#
#                 cpi_score_2019  healthcare_oop_expenditure  hospital_beds  \
# Country/Region
# Afghanistan               16.0                   77.401006            0.5
# Albania                   35.0                   57.980901            2.9
# Algeria                   35.0                   30.883271            1.9
# Angola                    26.0                   35.208930            NaN
# Argentina                 45.0                   15.798187            5.0
#
#                   hci  population_perc_over65  population_perc_rural  \
# Country/Region
# Afghanistan     0.389                2.584927                 74.505
# Albania         0.621               13.744736                 39.681
# Algeria         0.523                6.362497                 27.371
# Angola          0.361                2.216374                 34.486
# Argentina       0.611               11.117789                  8.130
#
#                 population_perc_diabetic  days_since_first_case_normalized  \
# Country/Region
# Afghanistan                          9.2                         -0.600000
# Albania                              9.0                         -0.733333
# Algeria                              6.7                         -0.609524
# Angola                               4.5                         -0.838095
# Argentina                            5.9                         -0.676190
#
#                 cpi_score_2019_normalized  \
# Country/Region
# Afghanistan                     -1.000000
# Albania                         -0.732394
# Algeria                         -0.732394
# Angola                          -0.859155
# Argentina                       -0.591549
#
#                 healthcare_oop_expenditure_normalized  \
# Country/Region
# Afghanistan                                  2.397450
# Albania                                      1.351901
# Algeria                                     -0.106994
# Angola                                       0.125893
# Argentina                                   -0.919152
#
#                 hospital_beds_normalized  hci_normalized  \
# Country/Region
# Afghanistan                    -1.056793       -1.244363
# Albania                        -0.075133        0.281341
# Algeria                        -0.484158       -0.363137
# Angola                               NaN       -1.428500
# Argentina                       0.783820        0.215578
#
#                 population_perc_over65_normalized  \
# Country/Region
# Afghanistan                             -1.036844
# Albania                                  0.666391
# Algeria                                 -0.460302
# Angola                                  -1.093093
# Argentina                                0.265461
#
#                 population_perc_rural_normalized  \
# Country/Region
# Afghanistan                             1.611667
# Albania                                 0.034435
# Algeria                                -0.523103
# Angola                                 -0.200854
# Argentina                              -1.394558
#
#                 population_perc_diabetic_normalized
# Country/Region
# Afghanistan                                0.412993
# Albania                                    0.362035
# Algeria                                   -0.223982
# Angola                                    -0.784521
# Argentina                                 -0.427814
